# %% [markdown]
# # Introduction

# %% [markdown]
# In the previous [tutorial](https://github.com/yanoak/data-extractors-tutorials/blob/master/python-for-extractives/01_Intro_to_Python/Intro_to_Python.ipynb), we learned the basics of programming with python and using the pandas library to work with data. We also introduced some programming concepts such as loops and functions.
#
# This tutorial will build on the programming skills that you acquired in the first tutorial. Specifically, we will cover concepts that are the nuts and bolts of programming in any language: loops, decisions and functions.
#
# Of course, we will also use examples from the extractives industry so that after working through this tutorial, you can get something concrete and useful that can be used in your work analysing the extractives industry.
#
# Mind you, the examples we will be showing in the beginning of this tutorial might seem not as directly useful, but trust me, you will be building up skills to write some powerful programs once you master loops, decisions and functions.

# %% [markdown]
# # Getting the data

# %% [markdown]
# The data that we will use for this tutorial will be from 2 sources. The first will be the same data from UK companies' mandatory disclosures that we used in the last tutorial. The other will be EITI (Extractive Industrities Transparency Initiative) data that is aggregated by NRGI (Natural Resources Governance Institute).
#
# ## Mandatory Disclosures Data
#
# We will be reading in CSV files that are downloaded from the UK Companies House Extractives Website https://extractives.companieshouse.gov.uk/
#
# I have downloaded all the files for all the companies that have reported as of April 2017 for financial year 2015. I've added them all to the 'data' folder of the Github repo that contains this tutorial.
#
# ## EITI Data
#
# NRGI has a wonderful data portal called [resourcedata.org](https://www.resourcedata.org/) which gathers a lot of data related to the extractives industry including EITI data. We will specifically use this [dataset](https://www.resourcedata.org/dataset/eiti-complete-summary-table/resource/bba3b646-131b-47c5-9f4c-37019f896575) that consolidates the summary datasheets of EITI data from all the reporting countries. I have downloaded the dataset and placed in the 'data' folder in the same Github repo as well.
#
# The easiest way to download all the data files as well as this tutorial is to go to the repo's main page and click on 'Clone or download' to get all the files as a zipped file.

# %% [markdown]
# # What we will learn in this tutorial

# %% [markdown]
# In this tutorial, we will cover basic programming concepts that anyone who is learning to code has to be familiar with.
#
# It is structured as follows:
# 1. For loops
# 2. While loops
# 3. Using 'if' and 'else' to make decisions
# 4. Writing your own functions
# 5. Writing a function that summarises EITI payments
# 6. Writing a function that summarises mandatory disclosure payments

# %% [markdown]
# 1. For loops
#     * simple example
#     * loop through EITI for UK License Fees in 2015
# 2. While loops
#     * loop through 1, 2, 3 till hits a certain sum
#     * loop through sorted payments till it exceeds a certain sum
# 3. Using 'if' and 'else' to make decisions
#     * silly example "a" and "an" for names
#     *
# 4. Writing your own functions

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import glob

# for index, row in df.iterrows():

# %% [markdown]
# # 1. For Loops

# %% [markdown]
# We have already encountered 'for' loops in tutorial 1. Let's do a quick refresher of what it is.
#
# We use a loop to tell a computer to do something repeatedly. A 'for' loop is one of the ways of writing a loop. Every programming language has it in some shape or form. In Python, a for loop iterates through a list of things, and it will repeated some lines of code that you have given it for each of the items in that list of things.

# %% [markdown]
# ## Silly Example
#
# As a silly first example, let's say you have a list of friends' names, and you want the computer to display the first letter of their names. Let's say your friends are Alex, Beth and Cedric. You want the computer to display:
#
# `Alex's name starts with A!`
# `Beth's name starts with B!`
# `Cedric's name starts with C!`
#
# ...and so on for every name in the list. It's silly, I know, but it will help you understand how this stuff works, we will move on to something more useful very soon.
#
# Let's write some code to do that!

# %%
friends_list = ["Alice", "Bob", "Cedric", "Dana", "Elizabeth", "Fergie"]

for f in friends_list:
    first_letter = f[0]
    print(f + "'s name starts with " + first_letter)
# Out:
# Alice's name starts with A
# Bob's name starts with B
# Cedric's name starts with C
# Dana's name starts with D
# Elizabeth's name starts with E
# Fergie's name starts with F

# %% [markdown]
# In three lines of code, we made the computer display as many lines of text as we want. Let's break it down.
#
# `friends_list = ["Alice", "Bob", "Cedric", "Dana", "Elizabeth", "Fergie"]` declares a list of strings, same as what we did in tutorial 1. This one is a list of six people's names.
#
# The next chunk declares the loop. The first line of the loop tells the computer what we are looping through. `for f in friends_list:` says that what follows will be the commands you want the program to run repeateded, for each element in `friends_list`. The `f` part of the line says that in each iteration, we will refer to the item in the list tha we are now at, as `f`. The `:` part says these following lines are what you want to run repeatedly.
#
# The lines that follow the first line have to be indented to let the computer know which lines are in the loop. Once you go back to unindented lines of code, the computer will know that those lines are not part of the loop.
#
# In the first iteration of the loop, `f` will be "Alice", then in the next iteration, `f` will be "Bob", and so on.
#
# `first_letter = f[0]` declares a new variable called `first_letter` which you assign the values `f[0]`. Remember `f` is equal to "Alice" in the fist iteration. Python treats strings of letters as lists in themselves as well. So, imagine the string `"Alice"` as a list `"[A,l,i,c,e]"`. Just like we can use `[]` to refer to things in a dataframe, we can use them to refer to elements of a list. so `f[0]` is the first element of `"[A,l,i,c,e]"`, i.e. `"A"`, and `f[2]` is `"i"`, etc.
#
# This means that in the first iteration, `first_letter = f[0]` assigns the value `"A"` to the variable `first_letter`.
#
# The function `print()` in the next line is used to display text on the screen. It will display whatever thing you put inside the `()` as a parameter. The `+` symbol can be used to combine bits of text, or "concetenate strings" in fancy promgramming speak. So, `print(f + "'s name starts with " + first_letter)` means it will display the value of `f` followed by `"'s name starts with "` followed by the value of `first_letter`.
#
# For the first iteration of the loop, `f` is `"Alice"` and `first_letter` is `"A"`. This means the `print()` function will display the line
#
# `Alice's name starts with A`.
#
# Following the same logic, in the next iteration, the program takes the next thing in the list, `"Bob"`, and assigns it to `f`. This means that `first_letter = f[0]` will now make `first_letter` take on the value `"B"`. Thus, the `print(f + "'s name starts with " + first_letter)` function will produce
#
# `Bob's name starts with B`
#
# and so on till we have not more items in the list to loop through.
#
# Got it? Go back to the code block above and change `friend_list` to something else, add more things or remove some things and run it again and see what you get.

# %% [markdown]
# ## Real World Example
#
# Now, let's use a for loop to work on some extractives data. We will use the EITI summary dataset that is in the "company-payments.csv" file inside the "data" folder. We will use a loop to display all the Licence Fees paid to the UK government in 2015.
#
# First we load the CSV file into a dataframe and filter for UK Licence Fee payments in 2015. If you have forgotten how to load and filter dataframes, please refer back to tutorial 1.

# %%
eiti_data = mydata = pd.read_csv('data/company-payments.csv')

# %%
eiti_data.head()
# Out:
#                     created                   changed      country iso3  year  \
# 0  2017-03-11T07:00:46+0000  2017-03-11T07:00:46+0000  Afghanistan  AFG  2009
# 1  2017-03-11T07:00:46+0000  2017-03-11T07:00:46+0000  Afghanistan  AFG  2009
# 2  2017-03-11T07:00:46+0000  2017-03-11T07:00:46+0000  Afghanistan  AFG  2009
# 3  2017-03-11T07:00:46+0000  2017-03-11T07:00:46+0000  Afghanistan  AFG  2009
# 4  2017-03-11T07:00:46+0000  2017-03-11T07:00:46+0000  Afghanistan  AFG  2009
#
#      start_date      end_date              company_name gfs_code  \
# 0  Mar 21, 2008  Mar 20, 2009   KUSHAK BROTHERS COMPANY  1415-E1
# 1  Mar 21, 2008  Mar 20, 2009   KUSHAK BROTHERS COMPANY  1415-E5
# 2  Mar 21, 2008  Mar 20, 2009   KUSHAK BROTHERS COMPANY   1421-E
# 3  Mar 21, 2008  Mar 20, 2009  NORTHERN COAL ENTERPRISE  1112-E1
# 4  Mar 21, 2008  Mar 20, 2009  NORTHERN COAL ENTERPRISE  1112-E1
#
#                                      gfs_description  \
# 0                                          Royalties
# 1                                Other rent payments
# 2    Sales of goods and services by government units
# 3  Ordinary taxes on income, profits and capital ...
# 4  Ordinary taxes on income, profits and capital ...
#
#                               name_of_revenue_stream currency_code  \
# 0       Revenue Stream: 1415E1 [Royalties] - Royalty           AFN
# 1  Revenue Stream: 1415E5 [Other rent payments] -...           AFN
# 2  Revenue Stream: 1421E [Sales of goods and serv...           AFN
# 3  Revenue Stream: 1112E1 [Ordinary taxes on inco...           AFN
# 4  Revenue Stream: 1112E1 [Ordinary taxes on inco...           AFN
#
#    currency_rate  value_reported  value_reported_as_USD  \
# 0          50.39      21950340.0               435609.0
# 1          50.39       1000000.0                19845.0
# 2          50.39         78000.0                 1548.0
# 3          50.39     111217004.0              2207125.0
# 4          50.39      14842880.0               294560.0
#
#                                   reporting_url
# 0  https://eiti.org/api/v1.0/organisation/32872
# 1  https://eiti.org/api/v1.0/organisation/32872
# 2  https://eiti.org/api/v1.0/organisation/32872
# 3  https://eiti.org/api/v1.0/organisation/32873
# 4  https://eiti.org/api/v1.0/organisation/32873

# %%
# The "\" at the end of the first line below is simply used to wrap a line of code
# that is too long so that it's easier to read. It doesn't add any functionality to the code

uk_2015 = eiti_data.loc[(eiti_data['country']=='United Kingdom') & (eiti_data['year']==2015) \
                        & (eiti_data['gfs_description']=="Licence fees")]

# %%
uk_2015.head()
# Out:
#                         created                   changed         country  \
# 40759  2017-05-16T07:00:55+0000  2017-05-16T07:00:55+0000  United Kingdom
# 40763  2017-05-16T07:00:55+0000  2017-05-16T07:00:55+0000  United Kingdom
# 40764  2017-05-16T07:00:55+0000  2017-05-16T07:00:55+0000  United Kingdom
# 40768  2017-05-16T07:00:55+0000  2017-05-16T07:00:55+0000  United Kingdom
# 40769  2017-05-16T07:00:55+0000  2017-05-16T07:00:55+0000  United Kingdom
#
#       iso3  year   start_date      end_date         company_name  gfs_code  \
# 40759  GBR  2015  Jan 1, 2015  Dec 31, 2015                   BP  114521-E
# 40763  GBR  2015  Jan 1, 2015  Dec 31, 2015  Centrica Energy E&P  114521-E
# 40764  GBR  2015  Jan 1, 2015  Dec 31, 2015  Centrica Energy E&P  114521-E
# 40768  GBR  2015  Jan 1, 2015  Dec 31, 2015       ConocoPhillips  114521-E
# 40769  GBR  2015  Jan 1, 2015  Dec 31, 2015       ConocoPhillips  114521-E
#
#       gfs_description                             name_of_revenue_stream  \
# 40759    Licence fees  Revenue Stream: 114521E [Licence fees] - Petro...
# 40763    Licence fees  Revenue Stream: 114521E [Licence fees] - Petro...
# 40764    Licence fees  Revenue Stream: 114521E [Licence fees] - Oil &...
# 40768    Licence fees  Revenue Stream: 114521E [Licence fees] - Petro...
# 40769    Licence fees  Revenue Stream: 114521E [Licence fees] - Oil &...
#
#       currency_code  currency_rate  value_reported  value_reported_as_USD  \
# 40759           GBP       0.673537       3569547.0              5299706.0
# 40763           GBP       0.673537       3874951.0              5753140.0
# 40764           GBP       0.673537        127210.0               188869.0
# 40768           GBP       0.673537       4922012.0              7307711.0
# 40769           GBP       0.673537        907098.0              1346768.0
#
#                                       reporting_url
# 40759  https://eiti.org/api/v1.0/organisation/35487
# 40763  https://eiti.org/api/v1.0/organisation/35488
# 40764  https://eiti.org/api/v1.0/organisation/35488
# 40768  https://eiti.org/api/v1.0/organisation/35489
# 40769  https://eiti.org/api/v1.0/organisation/35489

# %% [markdown]
# Now we have a dataframe called `uk_2015` that only consists of Licence payments to the UK government in 2015.
#
# Let's read through each line of this dataframe in a loop and print out a sentence describing the amount paid and which company paid it.
#
# Notice in the past we used a list to feed into a 'for' loop. Right now we don't have a list, but only a dataframe. So what do we do? Luckily there's a function you can call on a pandas dataframe that makes a dataframe into a list-like thing that you can feed into a 'for' loop. It's called `iterrows()`, and it returns 2 things, the index of the row and the data from the row itself. This slightly changes the way we declare the 'for' loop. Instead of having only one thing between the 'for' and 'in' (such as `for f in friends_list:`), we have two things seperated by a comma, the first one gets the index, and the second one gets the row data.

# %%
print("In 2015, the following companies paid License fees to the UK government as follows: \n")

total = 0

for index, row in uk_2015.iterrows():
    total = total + row["value_reported_as_USD"]
    print (row['company_name'] + " paid US$ " + str(row["value_reported_as_USD"]) + \
        " under the \n" + row["name_of_revenue_stream"] +"\n")
    
print("In total, the amount paid in License Fees was US$ " + str(total))
# Out:
# In 2015, the following companies paid License fees to the UK government as follows:
#
# BP paid US$ 5299706.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Centrica Energy E&P paid US$ 5753140.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Centrica Energy E&P paid US$ 188869.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# ConocoPhillips paid US$ 7307711.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# ConocoPhillips paid US$ 1346768.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Dana Petroleum paid US$ 722005.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Eni UK Limited paid US$ 1953347.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Eni UK Limited paid US$ 205257.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# ENGIE E&P UK Limited (formerly GDF SUEZ E&P UK Ltd) paid US$ 4348367.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# ENGIE E&P UK Limited (formerly GDF SUEZ E&P UK Ltd) paid US$ 275005.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# IGas Energy Group paid US$ 2084597.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Ithaca Energy (UK) Limited paid US$ 621743.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Ithaca Energy (UK) Limited paid US$ 225845.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# JX Nippon Exploration and Production (U.K.) Limited paid US$ 305217.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Maersk Oil North Sea UK Limited paid US$ 1913572.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Maersk Oil North Sea UK Limited paid US$ 320174.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Marathon Oil paid US$ 323100.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Marathon Oil paid US$ 135507.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# CNOOC [Nexen Petroluem U.K. Limited] paid US$ 7970511.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# CNOOC [Nexen Petroluem U.K. Limited] paid US$ 402214.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# OMV (U.K.) Limited paid US$ 3964479.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Perenco UK paid US$ 5829884.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Perenco UK paid US$ 1182586.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Premier Oil [incl E.ON Ruhrgas] paid US$ 4516925.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Premier Oil [incl E.ON Ruhrgas] paid US$ 562406.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Royal Dutch Shell Group paid US$ 3926396.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Royal Dutch Shell Group paid US$ 1494566.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Statoil (UK) Limited paid US$ 1741020.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Tullow Oil plc paid US$ 240299.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Tullow Oil plc paid US$ 135507.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Total Holdings UK Limited paid US$ 5572954.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Total Holdings UK Limited paid US$ 981216.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Hess Limited paid US$ 135507.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# CNR International (UK) Ltd paid US$ 508487.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# CNR International (UK) Ltd paid US$ 406520.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# EnQuest PLC paid US$ 2558866.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# EnQuest PLC paid US$ 459778.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Chevron North Sea Limited paid US$ 1363195.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Apache North Sea paid US$ 964368.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Apache North Sea paid US$ 279102.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Talisman Sinopec Energy UK Limited paid US$ 3906719.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Talisman Sinopec Energy UK Limited paid US$ 1256431.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Alpha Petroleum Resources Limited paid US$ 1938292.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Alpha Petroleum Resources Limited paid US$ 147797.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Endeavour Corp paid US$ 958738.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Endeavour Corp paid US$ 201157.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Faroe Petroleum paid US$ 1777305.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Faroe Petroleum paid US$ 139603.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Taqa Global paid US$ 1849276.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Taqa Global paid US$ 385931.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# INEOS INDUSTRIES  [incl. RWE DEA UK SNS Ltd] paid US$ 4199297.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# INEOS INDUSTRIES  [incl. RWE DEA UK SNS Ltd] paid US$ 385932.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# BG Group paid US$ 1633630.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# BG Group paid US$ 299691.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Other companies paid US$ 12098771.0 under the
# Revenue Stream: 114521E [Licence fees] - Petroleum Licence Fees
#
# Other companies paid US$ 1053701.0 under the
# Revenue Stream: 114521E [Licence fees] - Oil &amp; Gas Authority (OGA) Levy
#
# Other companies paid US$ 965330.0 under the
# Revenue Stream: 114521E [Licence fees] - Licensing and Permissions Charges
#
# In total, the amount paid in License Fees was US$ 111724317.0

# %% [markdown]
# First, let's go over few new things we introduced that you haven't seen before. The `str()` wrapped aound `row["value_reported_as_USD"]` converts a number into a string so that it can be combined with the other strings used in the `print()` function. The `"\n"` is like pressing Enter on the keyboard - it makes the text jump to a new line.

# %% [markdown]
# The rest of the code should be easy to understand. The first line just prints the fixed line "In 2015, the following companies paid License fees to the UK government as follows:". After that we initialise a variable called `total` that we will use to sum up the individual payments.
#
# The loop begins as we explained before with two things between the `for` and the `in` for the index and row given by the `.iterrows()` function. The next line adds the value of the payment in that row to the total in each iteration. The next line prints a sentence describing the company, the amount they paid, and the detailed Revenue Stream it was paid into.
#
# Notive that the final line is unindented, so it's not part of the loop, which means it's only executed once at the end of the loop. It just prints the total value that we have been calculating as we looped through each row. Check the output to see if it shows what we wanted.

# %% [markdown]
# ## What if I don't have a list and just want to repeat something X times?

# %% [markdown]
# Sometimes you're not trying to loop through the elements of a list and just want to have a loop that repeats some tasks for a set number of times. For that we use the `range()` function to generate a list on the fly.

# %%
range(0,5)
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in range(0,5):
    print("This is iteration number " + str(i))
# Out:
# This is iteration number 0
# This is iteration number 1
# This is iteration number 2
# This is iteration number 3
# This is iteration number 4

# %% [markdown]
# As seen above, you can use `range(0,number of times you want the loop to repeat)` in the declaration of the `for` loop to simply repeat things a set number of times.

# %% [markdown]
# # 2.  While Loops

# %% [markdown]
# 'For' loops aren't the only kinds of loops you can do in Python. Another kind is called the 'while' loop. The difference between the two is that whereas the 'for' loop requires a list with a fixed number of elements in it, the 'while' loop is one that keeps going for as long as a certain condition is met.
#
# Let's look at a silly example first.

# %% [markdown]
# ## Silly Example

# %%
sum = 0
i = 0

while (sum < 100):
    print("Adding " + str(i) + " to sum.") 
    sum = sum + i
    print("Sum is now " + str(sum))
    i = i + 1
# Out:
# Adding 0 to sum.
# Sum is now 0
# Adding 1 to sum.
# Sum is now 1
# Adding 2 to sum.
# Sum is now 3
# Adding 3 to sum.
# Sum is now 6
# Adding 4 to sum.
# Sum is now 10
# Adding 5 to sum.
# Sum is now 15
# Adding 6 to sum.
# Sum is now 21
# Adding 7 to sum.
# Sum is now 28
# Adding 8 to sum.
# Sum is now 36
# Adding 9 to sum.
# Sum is now 45
# Adding 10 to sum.
# Sum is now 55
# Adding 11 to sum.
# Sum is now 66
# Adding 12 to sum.
# Sum is now 78
# Adding 13 to sum.
# Sum is now 91
# Adding 14 to sum.
# Sum is now 105

# %% [markdown]
# What the above block of code does it to keep adding 0, 1, 2, 3... until the sum reaches 100.
#
# Just like in the 'for' loop, the 'while' loop starts off with a line that declares a loop. In this case it is
#
# `while (some condition)`
#
# Here we have set the condition to be that `sum < 100`. So, in each iteration of the loop, the program executes the lines of code that are indented, i.e.
#
# * printing the number that is being added,
# `print("Adding " + str(i) + " to sum.")`
#
# * adding the number to sum,
# `sum = sum + i`
#
# * printing the new sum,
# `print("Sum is now " + str(sum))`
#
# * and then adding 1 to get the number that we will add next.
# `i = i + 1`
#
# After that, it checks whether `sum < 100`, and if that condition still holds, it will execute that block of code again, and on and on until the time comes when `sum` is no longer less than `100`.
#
# That's the basic mechanism. So, you have to make sure that in that block of code, something is changing such that the condition will eventually be met.
#
# As we will cover in later tutorials, it might also be something external to your code that is changing that will make sure the condition will be met (such as requesting data from an online server until you've downloaded all the data you want from it).
#
# ### Be careful: While loops can be dangerous!
#
# As you can tell, since the loop goes on as long as that condition you set is met, there is always a risk that the while loop will never stop.
#
# If you want to see how that kind of scenerio looks like, go back to the above block of code, comment out the last line of the loop by putting a `#` in front of `i = i + 1` and run the block again.
#
# Now it won't stop because the code will just keep adding `0` to `sum` and it will never reach `100`. You'll have to click on "Kernel > Interupt" in the notebook's top menu to make it stop, and restart and run all again.
